# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os
working_directory=os.getcwd()
print(working_directory)
# Out:
# /Users/jiayiwang/Documents/Data_Career/Python/Python projects (data from Kaggle)/Food choices

# %%
path=working_directory + '/food_coded.csv'

# %%
df=pd.read_csv(path)

# %%
df.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          124 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# GPA                  2
# Gender               0
# breakfast            0
# calories_chicken     0
# calories_day        19
#                     ..
# type_sports         21
# veggies_day          0
# vitamins             0
# waffle_calories      0
# weight               2
# Length: 61, dtype: int64

# %%
df.describe()
# Out:
#            Gender   breakfast  calories_chicken  calories_day  calories_scone  \
# count  125.000000  125.000000        125.000000    106.000000      124.000000
# mean     1.392000    1.112000        577.320000      3.028302      505.241935
# std      0.490161    0.316636        131.214156      0.639308      230.840506
# min      1.000000    1.000000        265.000000      2.000000      315.000000
# 25%      1.000000    1.000000        430.000000      3.000000      420.000000
# 50%      1.000000    1.000000        610.000000      3.000000      420.000000
# 75%      2.000000    1.000000        720.000000      3.000000      420.000000
# max      2.000000    2.000000        720.000000      4.000000      980.000000
#
#           coffee  comfort_food_reasons_coded        cook  \
# count  125.00000                  106.000000  122.000000
# mean     1.75200                    2.698113    2.786885
# std      0.43359                    1.972042    1.038351
# ...

# %%
df.shape
# Out:
# (125, 61)

# %%
df.isnull().sum()
# Out:
# GPA                  2
# Gender               0
# breakfast            0
# calories_chicken     0
# calories_day        19
#                     ..
# type_sports         21
# veggies_day          0
# vitamins             0
# waffle_calories      0
# weight               2
# Length: 61, dtype: int64

# %%
df[['comfort_food_reasons','comfort_food_reasons_coded',  'comfort_food_reasons_coded.1']]
# Out:
#                               comfort_food_reasons  \
# 0                            we dont have comfort
# 1                             Stress, bored, anger
# 2                                  stress, sadness
# 3                                          Boredom
# 4                       Stress, boredom, cravings
# ..                                             ...
# 120                           boredom and sadness
# 121                Loneliness / Homesick / Sadness
# 122                                        sadness
# 123  happiness, they are some of my favorite foods
# 124               hormones, Premenstrual syndrome.
#
#      comfort_food_reasons_coded  comfort_food_reasons_coded.1
# 0                           9.0                             9
# 1                           1.0                             1
# 2                           1.0                             1
# 3                           2.0                             2
# ...

# %%
df[['comfort_food_reasons_coded',  'comfort_food_reasons_coded.1']].isnull().sum()
# Out:
# comfort_food_reasons_coded      19
# comfort_food_reasons_coded.1     0
# dtype: int64

# %%
df.drop('comfort_food_reasons_coded',axis=1)
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
total=df.isnull().sum().sort_values(ascending=False)
percent=(df.isnull().sum()/df.isnull().count()*100).round(1).sort_values(ascending=False)
nd=pd.concat({'NaN':total, 'Percentage of total':percent},axis=1)
nd.head(20)
# Out:
#                             NaN  Percentage of total
# type_sports                  21                 16.8
# calories_day                 19                 15.2
# comfort_food_reasons_coded   19                 15.2
# cuisine                      17                 13.6
# exercise                     13                 10.4
# employment                    9                  7.2
# cook                          3                  2.4
# eating_changes                3                  2.4
# father_profession             3                  2.4
# meals_dinner_friend           3                  2.4
# mother_education              3                  2.4
# weight                        2                  1.6
# mother_profession             2                  1.6
# drink                         2                  1.6
# fav_cuisine                   2                  1.6
# fav_food                      2                  1.6
# GPA                           2                  1.6
# ...

# %%
df['GPA'].unique()
# Out:
# array(['2.4', '3.654', '3.3', '3.2', '3.5', '2.25', '3.8', '3.904', '3.4',
#        '3.6', '3.1', nan, '4', '2.2', '3.87', '3.7', '3.9', '2.8', '3',
#        '3.65', '3.89', '2.9', '3.605', '3.83', '3.292', '3.35',
#        'Personal ', '2.6', '3.67', '3.73', '3.79 bitch', '2.71', '3.68',
#        '3.75', '3.92', 'Unknown', '3.77', '3.63', '3.882'], dtype=object)

# %%
df['GPA']=df['GPA'].str.replace(r'[^\d\.\d+]','').replace( '',np.nan).astype(float).round(2)
df['GPA']=df['GPA'].fillna(df['GPA'].mean())

# %%
sns.boxplot(df['GPA'])

# %%
df_new=df[df['GPA']>=2.50]

# %%
sns.boxplot(df_new['GPA'])

# %% [markdown]
# Obtaining the correlation between different cuisines with GPA above 2.5
#
# ethnic_food
# greek_food
# indian_food
# italian_food
# Persian_food
# thai_food
#
# How likely to eat these food when available?
# 1 - very unlikely
# 2 - unlikely
# 3 - neutral
# 4 - likely
# 5 - very likely

# %%
food_cat=['ethnic_food','greek_food','indian_food','italian_food','persian_food',
'thai_food']
c=sns.diverging_palette(240, 10, n=9)
sns.heatmap(df_new[food_cat].corr(method='spearman'),cmap=c, annot=True)

# %% [markdown]
# Obtaining correlation between diet type and GPA

# %%
diet_type=pd.get_dummies(df_new['diet_current_coded'])
diet_type=diet_type.rename(columns={1:'healthy/balanced/moderated/', 2:'unhealthy/cheap/too much/random/',3:'the same thing over and over',4:'unclear'})
diet_type['GPA']=df_new['GPA']
c=sns.diverging_palette(50, 10, as_cmap=True)
sns.heatmap(diet_type.corr(method='spearman'),cmap=c, annot=True)

# %%
ax=sns.countplot(df_new['Gender'])
ax.set_xticklabels(['Female','Male'],rotation=45,fontsize=10)
# Out:
# [Text(0, 0, 'Female'), Text(0, 0, 'Male')]

# %%
ax=sns.boxplot(x='Gender',y='GPA',data=df_new)
ax.set_xticklabels(['Female','Male'],rotation=45,fontsize=10)
# Out:
# [Text(0, 0, 'Female'), Text(0, 0, 'Male')]

# %%
gender_type=pd.get_dummies(df_new['Gender'])
gender_type=gender_type.rename(columns={1:'Female', 2:'Male'})
gender_type['GPA']=df_new['GPA']
c=sns.diverging_palette(50, 10, as_cmap=True)
sns.heatmap(gender_type.corr(method='spearman'),cmap=c, annot=True)

# %%
df_new['weight'].unique()
# Out:
# array(['155', "I'm not answering this. ", 'Not sure, 240', '190', '180',
#        '137', '125', '116', '110', '264', '123', '185', '145', '170',
#        '135', '175', '195', '105', '160', '167', '115', '205', nan, '128',
#        '150', '140', '120', '100', '113', '168', '169', '200', '265',
#        '165', '192', '118', '210', '112', '144 lbs', '130', '127', '129',
#        '260', '184', '230', '138', '156'], dtype=object)

# %%
df_new['weight']=df_new['weight'].str.replace(r'[^\d\d\d]', '').replace('',np.nan).astype(float)
# Out:
# /Users/jiayiwang/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new['weight'].unique()
# Out:
# array([155.,  nan, 240., 190., 180., 137., 125., 116., 110., 264., 123.,
#        185., 145., 170., 135., 175., 195., 105., 160., 167., 115., 205.,
#        128., 150., 140., 120., 100., 113., 168., 169., 200., 265., 165.,
#        192., 118., 210., 112., 144., 130., 127., 129., 260., 184., 230.,
#        138., 156.])

# %%
df_new['weight'].mean()
df_new['weight'] = df_new['weight'].fillna(df_new['weight'].mean())
# Out:
# /Users/jiayiwang/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ax=sns.catplot(x="type_sports", y="GPA",data=df_new,ax = ax,height=9, aspect=2.5, kind='box')
ax.set_xticklabels(rotation=90,fontsize=20)
# Out:
# /Users/jiayiwang/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3720: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try boxplot
#   warnings.warn(msg, UserWarning)

# %%
ax=sns.catplot(x="fav_cuisine", y="GPA",data=df_new,ax = ax,height=9, aspect=2.5, kind='box')
ax.set_xticklabels(rotation=90,fontsize=20)
# Out:
# /Users/jiayiwang/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3720: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try boxplot
#   warnings.warn(msg, UserWarning)

# %%
ax=sns.catplot(x="mother_profession", y="GPA",data=df_new,ax = ax,height=9, aspect=2.5, kind='box')
ax.set_xticklabels(rotation=90,fontsize=20)
# Out:
# /Users/jiayiwang/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3720: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try boxplot
#   warnings.warn(msg, UserWarning)

# %%
ax=sns.catplot(x="father_profession", y="GPA",data=df_new,ax = ax,height=9, aspect=2.5, kind='box')
ax.set_xticklabels(rotation=90,fontsize=20)
# Out:
# /Users/jiayiwang/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3720: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try boxplot
#   warnings.warn(msg, UserWarning)
